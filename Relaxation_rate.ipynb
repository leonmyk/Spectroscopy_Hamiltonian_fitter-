# %%
import numpy as np
0.03/0.001
# Out:
# 30.0

# %%
kappa = 1200*1e3
alpha = 0.000334/0.03 #amp elec rabi / amp sb rabi
sb_rabi = 28*1e3
elec_rabi = 8*1e3
A = 38.335*2*np.pi*1e3
WI = 763*2*np.pi*1e3
sb_detuning = 690*1e3


B = alpha * sb_rabi/elec_rabi * (2*WI + A)*np.sqrt(1+4*(sb_detuning/kappa)**2)
# n = B**2/(4*WI**2)*(1/(1+4*(WI**2/kappa**2)))
# n
B*1e-3/(2*np.pi)
# Out:
# 92.89682690635141

# %%
alpha
# Out:
# 0.11

# %%
import matplotlib.pyplot as plt 
p = 0.0005365654012731401
n = np.arange(400)

pvals = p*(1-p)**(n-1) 
relax_ps = np.array([pvals[:k].sum() for k in n])
plt.plot(n,relax_ps)

# %%
1/p
# Out:
# 1863.7057060094476

# %%
kappa = 1200
alpha = 0.001/0.05   #amp elec rabi / amp sb rabi
sb_rabi = 28
elec_rabi = 9.73
A = 38.335
WI = 802
sb_detuning = 690


B = alpha * sb_rabi/elec_rabi * (2*WI+A)*1/np.sqrt(1+4*(sb_detuning/kappa)**2)
n = B**2/(4*WI)*(1/(1+4*(WI/kappa)**2))
n
